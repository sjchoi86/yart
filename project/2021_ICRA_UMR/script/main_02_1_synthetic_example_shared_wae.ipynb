# %% [markdown]
# # Synthetic Example (Shared WAE)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from swae import run_swae_synthetic_experiment
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'    
print ("Ready.")
# Out:
# Ready.

# %% [markdown]
# ### Proposed Method (SWAE with DPP + SSL)

# %%
DATA_IMBALANCE = True
USE_DPP,USE_SSL = True,True
run_swae_synthetic_experiment(DATA_IMBALANCE=DATA_IMBALANCE,USE_DPP=USE_DPP,USE_SSL=USE_SSL)
print ("Done.")
# Out:
# n_x_dom:[80000], n_y_dom:[40000], n_glue:[20], n_ssl:[10000]
# [0][0.0%] X R:[2.764] D:[0.070] G:[0.069] WD:[0.000] / Y R:[1.968] D:[0.068] G:[0.069] WD:[0.000] / LC:[1.583] / NCE:[0.067] / X2Y:[26.316]
# Total loss is [32.975]. Avergae Absolute Error is [4.223].
# [0] Plot
# Avergae Absolute Error is [4.223].
# [1000][2.5%] X R:[0.008] D:[0.070] G:[0.069] WD:[0.000] / Y R:[0.000] D:[0.069] G:[0.067] WD:[0.000] / LC:[0.005] / NCE:[0.054] / X2Y:[0.055]
# Total loss is [0.398]. Avergae Absolute Error is [0.546].
# [2000][5.0%] X R:[0.002] D:[0.070] G:[0.069] WD:[0.000] / Y R:[0.002] D:[0.069] G:[0.068] WD:[0.000] / LC:[0.003] / NCE:[0.057] / X2Y:[0.023]
# Total loss is [0.362]. Avergae Absolute Error is [0.536].
# [3000][7.5%] X R:[0.001] D:[0.070] G:[0.069] WD:[0.000] / Y R:[0.000] D:[0.069] G:[0.068] WD:[0.000] / LC:[0.001] / NCE:[0.053] / X2Y:[0.007]
# Total loss is [0.338]. Avergae Absolute Error is [0.496].
# ...
